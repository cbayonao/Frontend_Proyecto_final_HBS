# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ramajudicial.gov.co/web/guest/portal/historico-de-noticias'
r = requests.get(url)

# %%
s = BeautifulSoup(r.text, 'lxml')
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="ltr" dir="ltr" lang="es-ES">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Histórico de Noticias - Rama Judicial
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="756dff77359a2ac7-f1fb83b340bd3456-ge3eb180825879f89-9" name="google-translate-customization"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:300,300i,400,400i,500,500i,700,700i,900" rel="stylesheet"/>
#   <script src="https://www.ramajudicial.gov.co/imagen-portal-rama-theme/js/jquery-1.9.1.min.js">
#   </script>
#   <script src="https://www.ramajudicial.gov.co/imagen-portal-rama-theme/js/jquery-3.3.1.min.js">
#   </script>
#   <script src="https://www.ramajudicial.gov.co/imagen-portal-rama-theme/js/jquery.cycle2.min.js">
#   </script>
#   <script src="https://www.ramajudicial.gov.co/imagen-portal-rama-theme/js/jquery.cycle2.carousel.min.js">
#   </script>
# ...
